# %%
import requests
from requests_oauthlib import OAuth1
import json
import pprint

# %%
with open('auth/secrets.json', 'r') as f:
    secrets = json.load(f)

# %%
AUTH_URL = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1(secrets['API_KEY'], secrets['API_SECRET'], secrets['ACCESS_TOKEN'], secrets['ACCESS_TOKEN_SECRET'])
requests.get(AUTH_URL, auth=auth)
# Out:
# <Response [200]>

# %%
r = requests.get('https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=stackoverflow&count=3&tweet_mode=extended', auth=auth)
for tweet in r.json():
  pprint.pprint(tweet)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Mar 14 14:55:41 +0000 2019',
#  'display_text_range': [0, 177],
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'builtinnyc.com/2019/03/12/nyc…',
#                         'expanded_url': 'https://www.builtinnyc.com/2019/03/12/nyc-startup-ctos',
#                         'indices': [154, 177],
#                         'url': 'https://t.co/4NLG5V5xM5'}],
#               'user_mentions': [{'id': 46014775,
#                                  'id_str': '46014775',
#                                  'indices': [29, 34],
#                                  'name': 'David Fullerton',
#                                  'screen_name': 'df07'},
#                                 {'id': 3372751879,
#                                  'id_str': '3372751879',
#                                  'indices': [118, 133],
#                                  'name': 'Built In NYC',
# ...
